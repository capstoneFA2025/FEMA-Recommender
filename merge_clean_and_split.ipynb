# %% [markdown]
# This notebook will perform our temporal train/test split of the dataset, after merging the two existing datasets into one and filtering out entries in the Disaster Declaration Summaries (DDS) that do not exist in the Mission Assignments (MA)

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
pd.set_option('display.max_columns', 80)

# %%
ma_filepath = 'mission_assignments.parquet'
dds_filepath = 'disaster_declaration_summaries.parquet'
train_filepath = 'combined_training_set.parquet'
test_filepath = 'combined_test_set.parquet'

# %%
# Load initial datasets

df_dds = pd.read_parquet(dds_filepath)
df_ma = pd.read_parquet(ma_filepath)
print(df_dds.shape, df_ma.shape)
# Out:
# (68485, 28) (40340, 39)

# %%
df_dds['designatedIncidentTypes'].head(10)
# Out:
# 0       R
# 1       R
# 2       R
# 3    None
# 4    None
# 5    None
# 6    None
# 7    None
# 8    None
# 9       R
# Name: designatedIncidentTypes, dtype: object

# %% [markdown]
# Adding lists and dictionaries for later use.

# %%
#dictionary to convert state/territory designators to full word strings
state_dict = {'AL':'Alabama','AK':'Alaska','AZ':'Arizona','AR':'Arkansas','CA':'California','CO':'Colorado','CT':'Connecticut',
             'DE':'Delaware', 'FL':'Florida','GA':'Georgia','HI':'Hawaii','ID':'Idaho','IL':'Illinois','IN':'Indiana','IA':'Iowa',
             'KS':'Kansas','KY':'Kentucky','LA':'Louisiana','ME':'Maine','MD':'Maryland','MA':'Massachusetts','MI':'Michigan',
             'MN':'Minnesota','MS':'Mississippi','MO':'Missouri','MT':'Montana','NE':'Nebraska','NV':'Nevada','NH':'New Hampshire',
             'NM':'New Mexico','NY':'New York','NJ':'New Jersey','NC':'North Carolina','ND':'North Dakota','OH':'Ohio',
             'OK':'Oklahoma','OR':'Oregon','PA':'Pennsylvania','RI':'Rhode Island','SC':'South Carolina','SD':'South Dakota',
             'TN':'Tennessee','TX':'Texas','UT':'Utah','VT':'Vermont','VA_state':'Virginia','WA':'Washington','WV':'West Virginia',
             'WI':'Wisconsin','WY':'Wyoming','DC':'Washington, DC','GU':'Guam','PR':'Puerto Rico','AS':'American Samoa',
             'MP':'Northern Mariana Islands','FM':'Federated States of Micronesia','MH':'Marshall Islands','PW':'Palau'}

state_list = ['AL','AZ','AR','CA','CO','CT','DE', 'FL','GA','ID','IL','IN','IA','KS','KY','LA','ME','MD','MA','MI',
             'MN','MS','MO','MT','NE','NV','NH','NM','NY','NJ','NC','ND','OH','OK','OR','PA','RI','SC','SD',
             'TN','TX','UT','VT','VA','WA','WV','WI','WY']

#set using only natural disasters that could be potentially caused by climate change
natural_disaster = ['Fire','Flood','Severe Storm','Straight-Line Winds','Winter Storm','Hurricane','Tornado','Tropical Storm',
                   'Mud/Landslide','Snowstorm','Coastal Storm','Severe Ice Storm','Typhoon','Freezing','Drought','Fishing Losses',
                   'Tropical Depression']

#manmade or other disasters that would not be caused by climate change
nonweather_disaster = ['Earthquake','Other','Biological','Dam/Levee Break','Volcanic Eruption','Toxic Substances','Chemical',
                      'Terrorist','Human Cause','Tsunami','Civil Unrest','Nuclear','Explosion','Tidal Wave']

#dictionary to convert disaster codes to strings representing each type of disaster
disaster_dict = {'0':'Not applicable','1':'Explosion','2':'Straight-Line Winds','3':'Tidal Wave','4':'Tropical Storm',
                '5':'Winter Storm','A':'Tsunami','B':'Biological','C':'Coastal Storm','D':'Drought','E':'Earthquake',
                'F':'Flood','G':'Freezing','H':'Hurricane','I':'Terrorist','J':'Typhoon','K':'Dam/Levee Break','L':'Chemical',
                'M':'Mud/Landslide','N':'Nuclear','O':'Severe Ice Storm','P':'Fishing Losses','Q':'Crop Losses','R':'Fire',
                'S':'Snowstorm','T':'Tornado','U':'Civil Unrest', 'V':'Volcanic Eruption','W':'Severe Storm','X':'Toxic Substances',
                'Y':'Human Cause','Z':'Other', '8':'Tropical Depression'}

agencyid_dict = {'CISA':'DHS-CISA','DHSMGMT':'DHS-MGMT','USDANRCS':'USDA-NRCS','GSA-':'GSA','VA-':'VA','EPA-':'EPA','DOT-':'DOT',
                'CNCS-':'CNCS','FCC-':'FCC','DOED':'DOE','DHUD':'HUD','DOD-':'DOD','VA -':'VA','USDAOCIO':'USDA-OCIO','FPS':'DHS-FPS',
                'TSA':'DHS-TSA','ICE':'DHS-ICE','USCIS':'DHS-CIS','DLA':'DOD-DLA','CBP':'DHS-CBP','NPS':'DOI-NPS','NPPD':'DHS-CISA',
                'CDC':'HHS-CDC','USAF':'DOD-USAF','OSHA':'DOL-OSHA','DHS-MGT':'DHS-MGMT','USGS':'DOI-USGS','USCG':'DHS-USCG',
                'USDJ':'DOJ','DHS-MGA':'DHS-IA','FLETC':'DHS-FLETC','DHS-FLET':'DHS-FLETC','USFS':'USDA-FS','HHS -PSC':'HHS-PSC'}

# %%
df_dds['designatedIncidentTypes'].sample(30)
# Out:
# 55589            W
# 1127       5,W,F,T
# 20806         None
# 12751         None
# 11755         None
# 19212         None
# 36133         None
# 6175          None
# 44694         None
# 40614         None
# 47278            T
# 14042         None
# 10591         None
# 3011          None
# 23714         None
# 26385         None
# 12296         None
# 56136         None
# 22746         None
# 38162            T
# 23283         None
# 41859            T
# 46671         None
# 59562            W
# 35856         None
# 45494         None
# 1983          None
# 35677         None
# 50938            F
# 14941    2,M,W,F,T
# Name: designatedIncidentTypes, dtype: object

# %% [markdown]
# Data cleaning for MA includes

# %%
df_ma=df_ma[(df_ma['declarationType']!='SU')&(df_ma['maAmendNumber']==0)&(df_ma['supportFunction']<=15)]

df_ma['supportFunction'].fillna(value=0,inplace=True)

# df_ma['stt'].replace({'VA':'VA_state'},inplace=True)

df_ma['agencyId'].replace(agencyid_dict,inplace=True)

column_list_ma = ['incidentId','stt','incidentType','region','maType','maPriority','supportFunction','agencyId', 'maId',
              'declarationType', 'assistanceRequested', 'statementOfWork']
df_ma = df_ma.reindex(columns=column_list_ma)

df_ma.drop_duplicates(inplace=True)

df_ma.rename(columns={'incidentType': 'incidentTypeMA'},
             inplace=True)

# df_ma.drop(columns=[
#     'lastRefresh',
#     'hash',
#     'id',],
#     inplace=True)

df_ma.shape
# Out:
# /var/folders/15/mh2mgzhn1191h4zq_5d03wfc0000gn/T/ipykernel_90853/1173886563.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ma['supportFunction'].fillna(value=0,inplace=True)
# /var/folders/15/mh2mgzhn1191h4zq_5d03wfc0000gn/T/ipykernel_90853/1173886563.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ma['agencyId'].replace(agencyid_dict,inplace=True)
# (7044, 12)

# %% [markdown]
# Data cleaning for DDS includes keeping of specific columns and filtering of year and declaration type

# %%
# select columns necessary for data analysis, add empty columns for each natural disaster type

column_list_dds = ['femaDeclarationString','state','incidentType','incidentBeginDate','fipsStateCode','region',
               'designatedIncidentTypes','declarationTitle', 'incidentId','declarationType']

df_dds = df_dds.reindex(
    columns=column_list_dds,
    fill_value=0)

# Add time information to DDS

df_dds['incidentBeginDate']=pd.to_datetime(df_dds['incidentBeginDate'])
df_dds['year'] = df_dds['incidentBeginDate'].dt.year
df_dds['month'] = df_dds['incidentBeginDate'].dt.month
df_dds['day'] = df_dds['incidentBeginDate'].dt.day

# Filter out values before 2012

df_dds=df_dds[(df_dds['year']>=2012) & (df_dds['declarationType']!='FM')]
# df_dds.drop(columns=[
#     'lastRefresh',
#     'hash',
#     'id',],
#     inplace=True)
print(df_dds.shape)

#ensures that incident type is reflected in designated incident types
df_dds['designatedIncidentTypes'].fillna(df_dds['incidentType'], inplace = True)

df_dds.drop_duplicates(inplace=True)
df_dds.reset_index(inplace = True,
                   drop=True)

df_dds.shape
# Out:
# (26041, 13)
# /var/folders/15/mh2mgzhn1191h4zq_5d03wfc0000gn/T/ipykernel_90853/1474806472.py:28: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_dds['designatedIncidentTypes'].fillna(df_dds['incidentType'], inplace = True)
# (1123, 13)

# %%
dds_column_list = df_dds.columns.to_list()
dds_column_list
# Out:
# ['femaDeclarationString',
#  'state',
#  'incidentType',
#  'incidentBeginDate',
#  'fipsStateCode',
#  'region',
#  'designatedIncidentTypes',
#  'declarationTitle',
#  'incidentId',
#  'declarationType',
#  'year',
#  'month',
#  'day']

# %%
df_ma.rename(columns={'stt':'state'},inplace=True)
ma_column_list = df_ma.columns.to_list()
ma_column_list
# Out:
# ['incidentId',
#  'state',
#  'incidentTypeMA',
#  'region',
#  'maType',
#  'maPriority',
#  'supportFunction',
#  'agencyId',
#  'maId',
#  'declarationType',
#  'assistanceRequested',
#  'statementOfWork']

# %%
print(df_dds['incidentId'].nunique(), df_ma['incidentId'].nunique())
# Out:
# 662 326

# %%
overlapping_columns = list(set(ma_column_list).intersection(set(dds_column_list)))
overlapping_columns
# Out:
# ['region', 'incidentId', 'declarationType', 'state']

# %%
MA_disaster_combined=df_ma.merge(
    df_dds, 
    how='left',
    on=overlapping_columns,
    validate='m:m')

# %%
MA_disaster_combined.shape
# Out:
# (7699, 21)

# %%
MA_disaster_combined.drop_duplicates(inplace=True)
MA_disaster_combined.shape
# Out:
# (7699, 21)

# %%
MA_disaster_combined['designatedIncidentTypes'].fillna(MA_disaster_combined['incidentTypeMA'], inplace = True)
# Out:
# /var/folders/15/mh2mgzhn1191h4zq_5d03wfc0000gn/T/ipykernel_90853/1635916619.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   MA_disaster_combined['designatedIncidentTypes'].fillna(MA_disaster_combined['incidentTypeMA'], inplace = True)

# %%
# MA_disaster_combined['designatedIncidentTypes'] = MA_disaster_combined['designatedIncidentTypes'].str.split(',')
# MA_disaster_combined['designatedIncidentTypes'] = MA_disaster_combined['designatedIncidentTypes'].replace(disaster_dict)
# MA_disaster_combined['designatedIncidentTypes'] = MA_disaster_combined['designatedIncidentTypes'].apply(
#     lambda x: (
#         [disaster_dict.get(s, s) for s in x]
#         if isinstance(x, list)
#         else x)
# )

# MA_disaster_combined['designatedIncidentTypes'].iloc[0]

MA_disaster_combined['designatedIncidentTypes'] = MA_disaster_combined['designatedIncidentTypes'].str.split(',').apply(
    lambda lst: [s.strip() for s in lst] if isinstance(lst, list) else lst).apply(
    lambda lst: [disaster_dict.get(s, s) for s in lst] if isinstance(lst, list) else lst).apply(
    lambda lst: ','.join(lst) if isinstance(lst, list) else str(lst))

# %%
MA_disaster_combined[['incidentTypeMA','designatedIncidentTypes']].sample(30)
# Out:
#            incidentTypeMA                            designatedIncidentTypes
# 102                  Fire                                               Fire
# 2574           Biological                                         Biological
# 5705            Hurricane                                          Hurricane
# 6846       Tropical Storm                           Tropical Storm,Hurricane
# 1371            Hurricane                                          Hurricane
# 2177           Biological                                         Biological
# 3623           Biological                                         Biological
# 7163  Tropical Depression                                Tropical Depression
# 2435           Biological                                         Biological
# 4906            Hurricane                                          Hurricane
# 6841       Tropical Storm  Tropical Storm,Tropical Depression,Mud/Landsli...
# 6818            Hurricane                                          Hurricane
# 3700           Biological                                         Biological
# 45                   Fire                                               Fire
# 4273                Flood                                              Flood
# 4012           Earthquake                                         Earthquake
# 3081           Biological                                         Biological
# 5302            Hurricane                                          Hurricane
# 4938            Hurricane                                          Hurricane
# 3254           Biological                                         Biological
# 936             Hurricane                                          Hurricane
# 2518           Biological                                         Biological
# 4590            Hurricane                                          Hurricane
# 5935            Hurricane                                          Hurricane
# 5937            Hurricane                                          Hurricane
# 202                 Flood                   Mud/Landslide,Severe Storm,Flood
# 4557            Hurricane                                          Hurricane
# 4692            Hurricane                                          Hurricane
# 3296           Biological                                         Biological
# 3652           Biological                                         Biological

# %%
type(MA_disaster_combined['designatedIncidentTypes'].iloc[0])
# Out:
# str

# %%
MA_disaster_combined.isna().sum()
# Out:
# incidentId                   0
# state                        0
# incidentTypeMA               0
# region                       0
# maType                       0
# maPriority                   0
# supportFunction              0
# agencyId                     0
# maId                         0
# declarationType              0
# assistanceRequested          0
# statementOfWork              0
# femaDeclarationString      156
# incidentType               156
# incidentBeginDate          156
# fipsStateCode              156
# designatedIncidentTypes      0
# declarationTitle           156
# year                       156
# month                      156
# day                        156
# dtype: int64

# %%
df_dds[df_dds['incidentId']==2024042701]
# Out:
#      femaDeclarationString state incidentType         incidentBeginDate  \
# 14              DR-4781-TX    TX        Flood 2024-04-26 00:00:00+00:00
# 1048            DR-4776-OK    OK      Tornado 2024-04-25 00:00:00+00:00
#
#       fipsStateCode  region designatedIncidentTypes  \
# 14               48       6                       W
# 1048             40       6                 2,W,F,T
#
#                                        declarationTitle  incidentId  \
# 14    SEVERE STORMS, STRAIGHT-LINE WINDS, TORNADOES,...  2024042701
# 1048  SEVERE STORMS, STRAIGHT-LINE WINDS, TORNADOES,...  2024042701
#
#      declarationType  year  month  day
# 14                DR  2024      4   26
# 1048              DR  2024      4   25

# %%
df_ma[df_ma['incidentId']==2024042701]
# Out:
#        incidentId state incidentTypeMA  region maType maPriority  \
# 401    2024042701    TX   Severe Storm       6    FOS       High
# 403    2024042701    TX   Severe Storm       6    FOS       High
# 404    2024042701    TX   Severe Storm       6    FOS       High
# 406    2024042701    TX   Severe Storm       6    FOS       High
# 408    2024042701    TX   Severe Storm       6    FOS       High
# 410    2024042701    TX   Severe Storm       6    FOS       High
# 411    2024042701    OK   Severe Storm       6    FOS       High
# 419    2024042701    OK   Severe Storm       6    FOS       High
# 29433  2024042701    TX   Severe Storm       6    FOS       High
# 29676  2024042701    OK   Severe Storm       6    FOS     Normal
# 30861  2024042701    OK   Severe Storm       6    FOS     Normal
#
#        supportFunction  agencyId                maId declarationType  \
# 401                6.0       HUD       4781DRTXHUD01              DR
# 403               12.0    DOE-OE    4781DRTXDOE-OE01              DR
# 404               13.0   DHS-FPS   4781DRTXDHS-FPS01              DR
# 406                2.0  DHS-CISA  4781DRTXDHS-CISA01              DR
# 408                3.0   COE-SWD   4781DRTXCOE-SWD02              DR
# 410                2.0  DHS-CISA      4781DRTXCISA01              DR
# 411                5.0  DOD-USAF  4776DROKDOD-USAF01              DR
# 419                3.0   COE-SWD   4776DROKCOE-SWD01              DR
# 29433              7.0       GSA       4781DRTXGSA01              DR
# 29676             13.0   DHS-FPS   4776DROKDHS-FPS01              DR
# 30861              7.0       GSA       4776DROKGSA01              DR
#
#                                      assistanceRequested  \
# 401    Request HUD specialized expertise to FEMA to s...
# 403    Activate DOE to RRCC. IOF, JFO, to include vir...
# 404    Request for Contract Security Officers to supp...
# 406    **This MA includes and replaces 4781DR-TX-CISA...
# 408    This MA replaces the verbal activation work an...
# 410    Activate CISA (ESF#2) to RRCC, IOF, JFO to inc...
# 411    This MA is being reissued under 4776DR-OK and ...
# 419    USACE specialized expertise for oversight of d...
# 29433  Activate and deploy GSA to RRCC, IOF, JFO, or ...
# 29676  Contract security officers to support the FEMA...
# 30861  This MA is being reissued under 4776DR-OK and ...
#
#                                          statementOfWork
# 401    As directed by and in coordination with FEMA, ...
# 403    As directed by and in coordination with FEMA, ...
# 404    As directed by and in coordination with FEMA, ...
# 406    As directed by and in coordination with FEMA, ...
# 408    As directed by and in coordination with FEMA, ...
# 410    As directed by and in coordination with FEMA, ...
# 411    As directed by and in coordination with FEMA, ...
# 419    As directed by and in coordination with FEMA, ...
# 29433  As directed by and in coordination with FEMA, ...
# 29676  As directed by and in coordination with FEMA, ...
# 30861  As directed by and in coordination with FEMA, ...

# %%
print(MA_disaster_combined[MA_disaster_combined['incidentTypeMA'].isna()]['incidentId'].value_counts())
print(MA_disaster_combined[MA_disaster_combined['incidentTypeMA'].isna()]['incidentId'].nunique())

ids_without_year = MA_disaster_combined[MA_disaster_combined['incidentTypeMA'].isna()]['incidentId'].tolist()
ids_without_year
# Out:
# Series([], Name: count, dtype: int64)
# 0
# []

# %%
df_dds[(df_dds['incidentId'].isin(ids_without_year))]
# Out:
# Empty DataFrame
# Columns: [femaDeclarationString, state, incidentType, incidentBeginDate, fipsStateCode, region, designatedIncidentTypes, declarationTitle, incidentId, declarationType, year, month, day]
# Index: []

# %%
df_ma[df_ma['incidentId']==2012102506]
# Out:
#        incidentId state incidentTypeMA  region maType maPriority  \
# 27259  2012102506    RI      Hurricane       1    FOS       High
# 27260  2012102506    CT      Hurricane       1    FOS       High
# 27261  2012102506    CT      Hurricane       1    FOS       High
# 27262  2012102506    CT      Hurricane       1    FOS     Normal
# 27263  2012102506    CT      Hurricane       1    FOS       High
# 27264  2012102506    CT      Hurricane       1    DFA       High
# 27265  2012102506    CT      Hurricane       1    FOS       High
# 27266  2012102506    CT      Hurricane       1    FOS       High
# 27267  2012102506    MA      Hurricane       1    FOS       High
#
#        supportFunction agencyId               maId declarationType  \
# 27259              7.0      GSA      3355EMRIGSA01              EM
# 27260              2.0      NCS      3353EMCTNCS01              EM
# 27261              8.0      HHS      3353EMCTHHS02              EM
# 27262              7.0      GSA      3353EMCTGSA01              EM
# 27263             12.0      DOE      3353EMCTDOE01              EM
# 27264              3.0  COE-NAD  3353EMCTCOE-NAD03              EM
# 27265              3.0  COE-NAD  3353EMCTCOE-NAD02              EM
# 27266              3.0  COE-NAD  3353EMCTCOE-NAD01              EM
# 27267              7.0      GSA      3350EMMAGSA01              EM
#
#                                      assistanceRequested  \
# 27259  Provide leasing specialists to support real es...
# 27260  Activate NCS in support of the RRCC and IMAT T...
# 27261  HHS deploy personnel from the Administration f...
# 27262  Activate General Services Administration (GSA)...
# 27263  Activate ESF-12, (Dept of energy) to the RRCC ...
# 27264  Provide emergency power generation to the affe...
# 27265  Activate and pre-position elements associated ...
# 27266  Activate Corps of Engineers to perform functio...
# 27267  Provide leasing specialist to support real est...
#
#                                          statementOfWork
# 27259  Obtain a suitable office to act as a Joint Fie...
# 27260  Activate National Communications System (NCS) ...
# 27261  For HHS to deploy approximately 2 personnel (s...
# 27262  Post-Declaration activation for appropriate GS...
# 27263  Pre-Declaration activation for appropriate DOE...
# 27264  Deploy the Emergency Power Planning and Respon...
# 27265  Pre-event actions include deployment of Planni...
# 27266  Activate U.S. Army Corps of Engineers (USACE) ...
# 27267  Obtain a suitable office to act as a Joint Fie...

# %%
MA_disaster_combined[(MA_disaster_combined['incidentId']==2012102506)&(MA_disaster_combined['year'].isna())]
# Out:
#       incidentId state incidentTypeMA  region maType maPriority  \
# 6525  2012102506    RI      Hurricane       1    FOS       High
# 6526  2012102506    CT      Hurricane       1    FOS       High
# 6527  2012102506    CT      Hurricane       1    FOS       High
# 6528  2012102506    CT      Hurricane       1    FOS     Normal
# 6529  2012102506    CT      Hurricane       1    FOS       High
# 6530  2012102506    CT      Hurricane       1    DFA       High
# 6531  2012102506    CT      Hurricane       1    FOS       High
# 6532  2012102506    CT      Hurricane       1    FOS       High
# 6533  2012102506    MA      Hurricane       1    FOS       High
#
#       supportFunction agencyId               maId declarationType  \
# 6525              7.0      GSA      3355EMRIGSA01              EM
# 6526              2.0      NCS      3353EMCTNCS01              EM
# 6527              8.0      HHS      3353EMCTHHS02              EM
# 6528              7.0      GSA      3353EMCTGSA01              EM
# 6529             12.0      DOE      3353EMCTDOE01              EM
# 6530              3.0  COE-NAD  3353EMCTCOE-NAD03              EM
# 6531              3.0  COE-NAD  3353EMCTCOE-NAD02              EM
# 6532              3.0  COE-NAD  3353EMCTCOE-NAD01              EM
# 6533              7.0      GSA      3350EMMAGSA01              EM
#
#                                     assistanceRequested  \
# 6525  Provide leasing specialists to support real es...
# 6526  Activate NCS in support of the RRCC and IMAT T...
# 6527  HHS deploy personnel from the Administration f...
# 6528  Activate General Services Administration (GSA)...
# 6529  Activate ESF-12, (Dept of energy) to the RRCC ...
# 6530  Provide emergency power generation to the affe...
# 6531  Activate and pre-position elements associated ...
# 6532  Activate Corps of Engineers to perform functio...
# 6533  Provide leasing specialist to support real est...
#
#                                         statementOfWork femaDeclarationString  \
# 6525  Obtain a suitable office to act as a Joint Fie...                   NaN
# 6526  Activate National Communications System (NCS) ...                   NaN
# 6527  For HHS to deploy approximately 2 personnel (s...                   NaN
# 6528  Post-Declaration activation for appropriate GS...                   NaN
# 6529  Pre-Declaration activation for appropriate DOE...                   NaN
# 6530  Deploy the Emergency Power Planning and Respon...                   NaN
# 6531  Pre-event actions include deployment of Planni...                   NaN
# 6532  Activate U.S. Army Corps of Engineers (USACE) ...                   NaN
# 6533  Obtain a suitable office to act as a Joint Fie...                   NaN
#
#      incidentType incidentBeginDate  fipsStateCode designatedIncidentTypes  \
# 6525          NaN               NaT            NaN               Hurricane
# 6526          NaN               NaT            NaN               Hurricane
# 6527          NaN               NaT            NaN               Hurricane
# 6528          NaN               NaT            NaN               Hurricane
# 6529          NaN               NaT            NaN               Hurricane
# 6530          NaN               NaT            NaN               Hurricane
# 6531          NaN               NaT            NaN               Hurricane
# 6532          NaN               NaT            NaN               Hurricane
# 6533          NaN               NaT            NaN               Hurricane
#
#      declarationTitle  year  month  day
# 6525              NaN   NaN    NaN  NaN
# 6526              NaN   NaN    NaN  NaN
# 6527              NaN   NaN    NaN  NaN
# 6528              NaN   NaN    NaN  NaN
# 6529              NaN   NaN    NaN  NaN
# 6530              NaN   NaN    NaN  NaN
# 6531              NaN   NaN    NaN  NaN
# 6532              NaN   NaN    NaN  NaN
# 6533              NaN   NaN    NaN  NaN

# %%
MA_disaster_combined[(MA_disaster_combined['incidentId']==2023052201)]
# Out:
#      incidentId state  incidentTypeMA  region maType       maPriority  \
# 469  2023052201    GU  Tropical Storm       9    FOS           Normal
# 470  2023052201    GU  Tropical Storm       9    FOS           Normal
# 471  2023052201    GU  Tropical Storm       9    FOS             High
# 472  2023052201    GU  Tropical Storm       9    DFA             High
# 473  2023052201    GU  Tropical Storm       9    FOS             High
# 474  2023052201    GU  Tropical Storm       9    FOS             High
# 475  2023052201    GU  Tropical Storm       9    FOS       Lifesaving
# 476  2023052201    GU  Tropical Storm       9    FOS           Normal
# 477  2023052201    GU  Tropical Storm       9    FOS             High
# 478  2023052201    GU  Tropical Storm       9    FOS           Normal
# 479  2023052201    GU  Tropical Storm       9    FOS  Life Sustaining
# 480  2023052201    GU  Tropical Storm       9    FOS           Normal
# 481  2023052201    GU  Tropical Storm       9    FOS             High
# 482  2023052201    GU  Tropical Storm       9    FOS             High
# 483  2023052201    GU  Tropical Storm       9    FOS             High
# 484  2023052201    GU  Tropical Storm       9    FOS             High
# 485  2023052201    GU  Tropical Storm       9    FOS             High
# 486  2023052201    GU  Tropical Storm       9    FOS           Normal
# 487  2023052201    GU  Tropical Storm       9    FOS             High
# 488  2023052201    GU  Tropical Storm       9    FOS           Normal
# 489  2023052201    GU  Tropical Storm       9    FOS             High
# 490  2023052201    GU  Tropical Storm       9    DFA             High
# 491  2023052201    GU  Tropical Storm       9    DFA             High
# 492  2023052201    GU  Tropical Storm       9    FOS             High
# 493  2023052201    GU  Tropical Storm       9    FOS             High
# 494  2023052201    GU  Tropical Storm       9    FOS             High
# 495  2023052201    GU  Tropical Storm       9    FOS             High
# 496  2023052201    GU  Tropical Storm       9    FOS             High
# 497  2023052201    GU  Tropical Storm       9    FOS             High
# 498  2023052201    GU  Tropical Storm       9    FOS             High
# 499  2023052201    GU  Tropical Storm       9    FOS             High
# 500  2023052201    GU  Tropical Storm       9    FOS             High
# 501  2023052201    GU  Tropical Storm       9    FOS             High
# 502  2023052201    GU  Tropical Storm       9    FOS             High
# 503  2023052201    GU  Tropical Storm       9    FOS             High
# 504  2023052201    GU  Tropical Storm       9    FOS             High
# 505  2023052201    GU  Tropical Storm       9    FOS             High
# 506  2023052201    GU  Tropical Storm       9    FOS           Normal
# 507  2023052201    GU  Tropical Storm       9    FOS             High
# 508  2023052201    GU  Tropical Storm       9    FOS             High
# 509  2023052201    GU  Tropical Storm       9    FOS           Normal
# 510  2023052201    GU  Tropical Storm       9    FOS           Normal
# 511  2023052201    GU  Tropical Storm       9    FOS             High
# 512  2023052201    GU  Tropical Storm       9    FOS             High
# 513  2023052201    GU  Tropical Storm       9    FOS             High
# 514  2023052201    GU  Tropical Storm       9    FOS             High
# 515  2023052201    GU  Tropical Storm       9    FOS             High
# 516  2023052201    GU  Tropical Storm       9    FOS             High
# 517  2023052201    GU  Tropical Storm       9    DFA           Normal
# 518  2023052201    GU  Tropical Storm       9    FOS           Normal
# 519  2023052201    GU  Tropical Storm       9    FOS             High
#
#      supportFunction  agencyId                maId declarationType  \
# 469              4.0   USDA-FS   4715DRGUUSDA-FS01              DR
# 470             11.0  USDA-APH  4715DRGUUSDA-APH02              DR
# 471             11.0  USDA-APH  4715DRGUUSDA-APH01              DR
# 472              8.0  HHS-ASPR  4715DRGUHHS-ASPR04              DR
# 473              8.0  HHS-ASPR  4715DRGUHHS-ASPR03              DR
# 474              8.0  HHS-ASPR  4715DRGUHHS-ASPR02              DR
# 475              8.0  HHS-ASPR  4715DRGUHHS-ASPR01              DR
# 476              7.0       GSA       4715DRGUGSA02              DR
# 477              7.0       GSA       4715DRGUGSA01              DR
# 478              2.0       FCC       4715DRGUFCC01              DR
# 479              3.0       EPA       4715DRGUEPA04              DR
# 480             10.0       EPA       4715DRGUEPA03              DR
# 481              3.0       EPA       4715DRGUEPA02              DR
# 482             10.0       EPA       4715DRGUEPA01              DR
# 483              1.0       DOT       4715DRGUDOT02              DR
# 484              1.0       DOT       4715DRGUDOT01              DR
# 485              0.0       DOS       4715DRGUDOS01              DR
# 486             13.0   DOJ-ATF   4715DRGUDOJ-ATF02              DR
# 487             13.0   DOJ-ATF   4715DRGUDOJ-ATF01              DR
# 488             12.0    DOE-OE    4715DRGUDOE-OE02              DR
# 489             12.0    DOE-OE    4715DRGUDOE-OE01              DR
# 490              0.0   DOD-OPS   4715DRGUDOD-OPS16              DR
# 491              0.0   DOD-OPS   4715DRGUDOD-OPS15              DR
# 492              0.0   DOD-OPS   4715DRGUDOD-OPS14              DR
# 493              0.0   DOD-OPS   4715DRGUDOD-OPS12              DR
# 494              0.0   DOD-OPS   4715DRGUDOD-OPS11              DR
# 495              7.0   DOD-OPS   4715DRGUDOD-OPS10              DR
# 496              7.0   DOD-OPS   4715DRGUDOD-OPS09              DR
# 497              7.0   DOD-OPS   4715DRGUDOD-OPS08              DR
# 498              7.0   DOD-OPS   4715DRGUDOD-OPS07              DR
# 499              7.0   DOD-OPS   4715DRGUDOD-OPS06              DR
# 500              7.0   DOD-OPS   4715DRGUDOD-OPS05              DR
# 501              0.0   DOD-OPS   4715DRGUDOD-OPS04              DR
# 502              0.0   DOD-OPS   4715DRGUDOD-OPS03              DR
# 503              0.0   DOD-OPS   4715DRGUDOD-OPS02              DR
# 504              5.0   DOD-OPS   4715DRGUDOD-OPS01              DR
# 505              7.0   DOD-DLA       4715DRGUDLA01              DR
# 506              0.0  DHS-USCG  4715DRGUDHS-USCG04              DR
# 507              0.0  DHS-USCG  4715DRGUDHS-USCG02              DR
# 508              0.0  DHS-USCG  4715DRGUDHS-USCG01              DR
# 509             13.0   DHS-FPS   4715DRGUDHS-FPS01              DR
# 510             14.0  DHS-CISA  4715DRGUDHS-CISA04              DR
# 511              2.0  DHS-CISA  4715DRGUDHS-CISA03              DR
# 512             14.0  DHS-CISA  4715DRGUDHS-CISA02              DR
# 513              2.0  DHS-CISA  4715DRGUDHS-CISA01              DR
# 514              3.0   COE-POD   4715DRGUCOE-POD05              DR
# 515              3.0   COE-POD   4715DRGUCOE-POD04              DR
# 516              6.0   COE-POD   4715DRGUCOE-POD03              DR
# 517              3.0   COE-POD   4715DRGUCOE-POD02              DR
# 518              3.0   COE-POD   4715DRGUCOE-POD01              DR
# 519              3.0    COE-HQ    4715DRGUCOE-HQ01              DR
#
#                                    assistanceRequested  \
# 469  Activate ESF 4 USFS to the RRCC, IOF JFO or ot...
# 470  Activate ESF 11 USDA liaison(s) to the  RRCC, ...
# 471  USDA liaison(s) to the NRCC to perform duties ...
# 472  HHS to provide DMAT team in support of MAWAR\r...
# 473  Activate HHS to RRCC, IOF, JFO, RFO, or other ...
# 474       HHS to provide DMAT team in support of MAWAR
# 475  Activate HHS to NRCC to perform duties of ESF ...
# 476  Activate ESF 7 GSA to RRCC, IOF, JFO, or other...
# 477  Activate GSA to NRCC to perform duties of ESF ...
# 478  Activate FCC to the NRCC to support Typhoon MA...
# 479  Region 9 Water Emergency Team (WET) SME to sup...
# 480  Activate ESF 10 EPA to RRCC, IOF, JFO, or othe...
# 481  Water/Wastewater SME to NRCC. This MA is repla...
# 482  EPA to NRCC to perform duties of ESF #10 in su...
# 483  Activate ESF 1 DOT to RRCC. IOF, JFO, or other...
# 484  Activate Dot to NRCC to support Typhoon Mawar....
# 485  Activate DOS to the NRCC to perform LNO duties...
# 486  Activate ESF 13 DOJ to RRCC, IOF, JFO, or othe...
# 487  Activate DOJ to NRCC to perform duties of ESF ...
# 488  Activate DOE to RRCC. IOF, JFO, or other team(...
# 489  Activate DOE to the NRCC to perform duties of ...
# 490  Request for assistance with temporary housing ...
# 491  DOD to provide debris clearance for to the rig...
# 492  Provide Joint Base Pearl Harbor Hickam (JBPHH)...
# 493  (DOD) will provide Material Handling Capabilit...
# 494  DOD to provide manpower and equipment in suppo...
# 495  DoD will provide Interisland air  transportati...
# 496  Provide ground transportation to move cargo an...
# 497  DOD strategic air transportation of personnel ...
# 498  Provide interisland transportation (Sea) of su...
# 499  DOD to provide Andersen Airforce Base as a FEM...
# 500   DOD provide Navel Base Guam  and support faci...
# 501  Request DCO / DCE West (including as necessary...
# 502  Request DCO / DCE East (including as necessary...
# 503  Request DCO / DCE Oakland (including as necess...
# 504  Activate DOD to NRCC to support Typhoon Mawar....
# 505  Activate DLA liaisons to NRCC in support of Ty...
# 506  USCG fixed-wing transportation of personnel an...
# 507  Request to deploy USCG liaison officer(s) to R...
# 508  Activate USCG liaison(s) to NRCC in support of...
# 509  Contract security officers to support the FEMA...
# 510  Activate CISA-14 LNOs to RRCC, JFO, IOF. This ...
# 511  Activate CISA ESF-2 to RRCC, IOF, JFO. \r\nThi...
# 512  Activate CISA LNO to NRCC to perform duties of...
# 513  Activate CISA to the NRCC to perform duties of...
# 514  USACE specialized expertise for oversight of d...
# 515  USACE pre-position resources to provide planni...
# 516  USACE pre-position the Temporary Roofing SME P...
# 517  USACE will provide temporary power support ass...
# 518  Activate ESF #3 USACE to the EOC, RRCC, IOF, J...
# 519  Activate USACE to the NRCC in support of Typho...
#
#                                        statementOfWork femaDeclarationString  \
# 469  As directed by and in coordination with FEMA, ...                   NaN
# 470  As directed by and in coordination with FEMA, ...                   NaN
# 471  As directed by and in coordination with FEMA, ...                   NaN
# 472  In support of Guam as directed by and in coord...                   NaN
# 473  As directed by and in coordination with FEMA, ...                   NaN
# 474  In support of Guam as directed by and in coord...                   NaN
# 475  As directed by and in coordination with FEMA, ...                   NaN
# 476  As directed by and in coordination with FEMA, ...                   NaN
# 477  As directed by and in coordination with FEMA, ...                   NaN
# 478  As directed by and in coordination with FEMA, ...                   NaN
# 479  As directed by and in coordination with FEMA, ...                   NaN
# 480  As directed by and in coordination with FEMA, ...                   NaN
# 481  As directed by and in coordination with FEMA, ...                   NaN
# 482  As directed by and in coordination with FEMA, ...                   NaN
# 483  .As directed by and in coordination with FEMA,...                   NaN
# 484  As directed by and in coordination with FEMA, ...                   NaN
# 485  As directed by and in coordination with FEMA, ...                   NaN
# 486  As directed by and in coordination with FEMA, ...                   NaN
# 487  As directed by and in coordination with FEMA, ...                   NaN
# 488  As directed by and in coordination with FEMA, ...                   NaN
# 489  As directed by and in coordination with FEMA, ...                   NaN
# 490  DOD to provide personnel, equipment, supplies ...                   NaN
# 491  As requested by and in coordination with FEMA,...                   NaN
# 492  As requested by and in coordination with FEMA,...                   NaN
# 493  As directed by and in coordination with FEMA, ...                   NaN
# 494  As directed by and in coordination with FEMA, ...                   NaN
# 495  As requested by and in coordination with FEMA ...                   NaN
# 496  As requested by and in coordination with FEMA ...                   NaN
# 497  As requested by and in coordination with FEMA ...                   NaN
# 498  As requested by and in coordination with FEMA ...                   NaN
# 499  As requested by and in coordination with FEMA,...                   NaN
# 500  As directed by and in coordination with FEMA, ...                   NaN
# 501  As directed by and in coordination with FEMA, ...                   NaN
# 502  As directed by and in coordination with FEMA, ...                   NaN
# 503  As directed by and in coordination with FEMA, ...                   NaN
# 504  As directed by and in coordination with FEMA, ...                   NaN
# 505  As directed by and in coordination with FEMA, ...                   NaN
# 506  As directed by and in coordination with FEMA, ...                   NaN
# 507  As directed by and in coordination with FEMA, ...                   NaN
# 508  As directed by and in coordination with FEMA, ...                   NaN
# 509  As directed by and in coordination with FEMA, ...                   NaN
# 510  As directed by and in coordination with FEMA, ...                   NaN
# 511  As directed by and in coordination with FEMA, ...                   NaN
# 512  As directed by and in coordination with FEMA, ...                   NaN
# 513  As directed by and in coordination with FEMA, ...                   NaN
# 514  As directed by and in coordination with FEMA, ...                   NaN
# 515  As directed by and in coordination with FEMA, ...                   NaN
# 516  As directed by and in coordination with FEMA, ...                   NaN
# 517  In support of Guam request, as directed by and...                   NaN
# 518  As directed by and in coordination with FEMA, ...                   NaN
# 519  As directed by and in coordination with FEMA, ...                   NaN
#
#     incidentType incidentBeginDate  fipsStateCode designatedIncidentTypes  \
# 469          NaN               NaT            NaN          Tropical Storm
# 470          NaN               NaT            NaN          Tropical Storm
# 471          NaN               NaT            NaN          Tropical Storm
# 472          NaN               NaT            NaN          Tropical Storm
# 473          NaN               NaT            NaN          Tropical Storm
# 474          NaN               NaT            NaN          Tropical Storm
# 475          NaN               NaT            NaN          Tropical Storm
# 476          NaN               NaT            NaN          Tropical Storm
# 477          NaN               NaT            NaN          Tropical Storm
# 478          NaN               NaT            NaN          Tropical Storm
# 479          NaN               NaT            NaN          Tropical Storm
# 480          NaN               NaT            NaN          Tropical Storm
# 481          NaN               NaT            NaN          Tropical Storm
# 482          NaN               NaT            NaN          Tropical Storm
# 483          NaN               NaT            NaN          Tropical Storm
# 484          NaN               NaT            NaN          Tropical Storm
# 485          NaN               NaT            NaN          Tropical Storm
# 486          NaN               NaT            NaN          Tropical Storm
# 487          NaN               NaT            NaN          Tropical Storm
# 488          NaN               NaT            NaN          Tropical Storm
# 489          NaN               NaT            NaN          Tropical Storm
# 490          NaN               NaT            NaN          Tropical Storm
# 491          NaN               NaT            NaN          Tropical Storm
# 492          NaN               NaT            NaN          Tropical Storm
# 493          NaN               NaT            NaN          Tropical Storm
# 494          NaN               NaT            NaN          Tropical Storm
# 495          NaN               NaT            NaN          Tropical Storm
# 496          NaN               NaT            NaN          Tropical Storm
# 497          NaN               NaT            NaN          Tropical Storm
# 498          NaN               NaT            NaN          Tropical Storm
# 499          NaN               NaT            NaN          Tropical Storm
# 500          NaN               NaT            NaN          Tropical Storm
# 501          NaN               NaT            NaN          Tropical Storm
# 502          NaN               NaT            NaN          Tropical Storm
# 503          NaN               NaT            NaN          Tropical Storm
# 504          NaN               NaT            NaN          Tropical Storm
# 505          NaN               NaT            NaN          Tropical Storm
# 506          NaN               NaT            NaN          Tropical Storm
# 507          NaN               NaT            NaN          Tropical Storm
# 508          NaN               NaT            NaN          Tropical Storm
# 509          NaN               NaT            NaN          Tropical Storm
# 510          NaN               NaT            NaN          Tropical Storm
# 511          NaN               NaT            NaN          Tropical Storm
# 512          NaN               NaT            NaN          Tropical Storm
# 513          NaN               NaT            NaN          Tropical Storm
# 514          NaN               NaT            NaN          Tropical Storm
# 515          NaN               NaT            NaN          Tropical Storm
# 516          NaN               NaT            NaN          Tropical Storm
# 517          NaN               NaT            NaN          Tropical Storm
# 518          NaN               NaT            NaN          Tropical Storm
# 519          NaN               NaT            NaN          Tropical Storm
#
#     declarationTitle  year  month  day
# 469              NaN   NaN    NaN  NaN
# 470              NaN   NaN    NaN  NaN
# 471              NaN   NaN    NaN  NaN
# 472              NaN   NaN    NaN  NaN
# 473              NaN   NaN    NaN  NaN
# 474              NaN   NaN    NaN  NaN
# 475              NaN   NaN    NaN  NaN
# 476              NaN   NaN    NaN  NaN
# 477              NaN   NaN    NaN  NaN
# 478              NaN   NaN    NaN  NaN
# 479              NaN   NaN    NaN  NaN
# 480              NaN   NaN    NaN  NaN
# 481              NaN   NaN    NaN  NaN
# 482              NaN   NaN    NaN  NaN
# 483              NaN   NaN    NaN  NaN
# 484              NaN   NaN    NaN  NaN
# 485              NaN   NaN    NaN  NaN
# 486              NaN   NaN    NaN  NaN
# 487              NaN   NaN    NaN  NaN
# 488              NaN   NaN    NaN  NaN
# 489              NaN   NaN    NaN  NaN
# 490              NaN   NaN    NaN  NaN
# 491              NaN   NaN    NaN  NaN
# 492              NaN   NaN    NaN  NaN
# 493              NaN   NaN    NaN  NaN
# 494              NaN   NaN    NaN  NaN
# 495              NaN   NaN    NaN  NaN
# 496              NaN   NaN    NaN  NaN
# 497              NaN   NaN    NaN  NaN
# 498              NaN   NaN    NaN  NaN
# 499              NaN   NaN    NaN  NaN
# 500              NaN   NaN    NaN  NaN
# 501              NaN   NaN    NaN  NaN
# 502              NaN   NaN    NaN  NaN
# 503              NaN   NaN    NaN  NaN
# 504              NaN   NaN    NaN  NaN
# 505              NaN   NaN    NaN  NaN
# 506              NaN   NaN    NaN  NaN
# 507              NaN   NaN    NaN  NaN
# 508              NaN   NaN    NaN  NaN
# 509              NaN   NaN    NaN  NaN
# 510              NaN   NaN    NaN  NaN
# 511              NaN   NaN    NaN  NaN
# 512              NaN   NaN    NaN  NaN
# 513              NaN   NaN    NaN  NaN
# 514              NaN   NaN    NaN  NaN
# 515              NaN   NaN    NaN  NaN
# 516              NaN   NaN    NaN  NaN
# 517              NaN   NaN    NaN  NaN
# 518              NaN   NaN    NaN  NaN
# 519              NaN   NaN    NaN  NaN

# %%
df_ma[df_ma['incidentId']==2023052201]
# Out:
#       incidentId state  incidentTypeMA  region maType       maPriority  \
# 1773  2023052201    GU  Tropical Storm       9    FOS           Normal
# 1776  2023052201    GU  Tropical Storm       9    FOS           Normal
# 1778  2023052201    GU  Tropical Storm       9    FOS             High
# 1781  2023052201    GU  Tropical Storm       9    DFA             High
# 1782  2023052201    GU  Tropical Storm       9    FOS             High
# 1784  2023052201    GU  Tropical Storm       9    FOS             High
# 1785  2023052201    GU  Tropical Storm       9    FOS       Lifesaving
# 1789  2023052201    GU  Tropical Storm       9    FOS           Normal
# 1790  2023052201    GU  Tropical Storm       9    FOS             High
# 1792  2023052201    GU  Tropical Storm       9    FOS           Normal
# 1795  2023052201    GU  Tropical Storm       9    FOS  Life Sustaining
# 1797  2023052201    GU  Tropical Storm       9    FOS           Normal
# 1798  2023052201    GU  Tropical Storm       9    FOS             High
# 1799  2023052201    GU  Tropical Storm       9    FOS             High
# 1801  2023052201    GU  Tropical Storm       9    FOS             High
# 1803  2023052201    GU  Tropical Storm       9    FOS             High
# 1805  2023052201    GU  Tropical Storm       9    FOS             High
# 1807  2023052201    GU  Tropical Storm       9    FOS           Normal
# 1809  2023052201    GU  Tropical Storm       9    FOS             High
# 1812  2023052201    GU  Tropical Storm       9    FOS           Normal
# 1814  2023052201    GU  Tropical Storm       9    FOS             High
# 1816  2023052201    GU  Tropical Storm       9    DFA             High
# 1818  2023052201    GU  Tropical Storm       9    DFA             High
# 1820  2023052201    GU  Tropical Storm       9    FOS             High
# 1823  2023052201    GU  Tropical Storm       9    FOS             High
# 1825  2023052201    GU  Tropical Storm       9    FOS             High
# 1828  2023052201    GU  Tropical Storm       9    FOS             High
# 1831  2023052201    GU  Tropical Storm       9    FOS             High
# 1838  2023052201    GU  Tropical Storm       9    FOS             High
# 1840  2023052201    GU  Tropical Storm       9    FOS             High
# 1842  2023052201    GU  Tropical Storm       9    FOS             High
# 1844  2023052201    GU  Tropical Storm       9    FOS             High
# 1851  2023052201    GU  Tropical Storm       9    FOS             High
# 1856  2023052201    GU  Tropical Storm       9    FOS             High
# 1860  2023052201    GU  Tropical Storm       9    FOS             High
# 1863  2023052201    GU  Tropical Storm       9    FOS             High
# 1865  2023052201    GU  Tropical Storm       9    FOS             High
# 1867  2023052201    GU  Tropical Storm       9    FOS           Normal
# 1871  2023052201    GU  Tropical Storm       9    FOS             High
# 1873  2023052201    GU  Tropical Storm       9    FOS             High
# 1877  2023052201    GU  Tropical Storm       9    FOS           Normal
# 1879  2023052201    GU  Tropical Storm       9    FOS           Normal
# 1882  2023052201    GU  Tropical Storm       9    FOS             High
# 1884  2023052201    GU  Tropical Storm       9    FOS             High
# 1886  2023052201    GU  Tropical Storm       9    FOS             High
# 1890  2023052201    GU  Tropical Storm       9    FOS             High
# 1893  2023052201    GU  Tropical Storm       9    FOS             High
# 1898  2023052201    GU  Tropical Storm       9    FOS             High
# 1905  2023052201    GU  Tropical Storm       9    DFA           Normal
# 1914  2023052201    GU  Tropical Storm       9    FOS           Normal
# 1916  2023052201    GU  Tropical Storm       9    FOS             High
#
#       supportFunction  agencyId                maId declarationType  \
# 1773              4.0   USDA-FS   4715DRGUUSDA-FS01              DR
# 1776             11.0  USDA-APH  4715DRGUUSDA-APH02              DR
# 1778             11.0  USDA-APH  4715DRGUUSDA-APH01              DR
# 1781              8.0  HHS-ASPR  4715DRGUHHS-ASPR04              DR
# 1782              8.0  HHS-ASPR  4715DRGUHHS-ASPR03              DR
# 1784              8.0  HHS-ASPR  4715DRGUHHS-ASPR02              DR
# 1785              8.0  HHS-ASPR  4715DRGUHHS-ASPR01              DR
# 1789              7.0       GSA       4715DRGUGSA02              DR
# 1790              7.0       GSA       4715DRGUGSA01              DR
# 1792              2.0       FCC       4715DRGUFCC01              DR
# 1795              3.0       EPA       4715DRGUEPA04              DR
# 1797             10.0       EPA       4715DRGUEPA03              DR
# 1798              3.0       EPA       4715DRGUEPA02              DR
# 1799             10.0       EPA       4715DRGUEPA01              DR
# 1801              1.0       DOT       4715DRGUDOT02              DR
# 1803              1.0       DOT       4715DRGUDOT01              DR
# 1805              0.0       DOS       4715DRGUDOS01              DR
# 1807             13.0   DOJ-ATF   4715DRGUDOJ-ATF02              DR
# 1809             13.0   DOJ-ATF   4715DRGUDOJ-ATF01              DR
# 1812             12.0    DOE-OE    4715DRGUDOE-OE02              DR
# 1814             12.0    DOE-OE    4715DRGUDOE-OE01              DR
# 1816              0.0   DOD-OPS   4715DRGUDOD-OPS16              DR
# 1818              0.0   DOD-OPS   4715DRGUDOD-OPS15              DR
# 1820              0.0   DOD-OPS   4715DRGUDOD-OPS14              DR
# 1823              0.0   DOD-OPS   4715DRGUDOD-OPS12              DR
# 1825              0.0   DOD-OPS   4715DRGUDOD-OPS11              DR
# 1828              7.0   DOD-OPS   4715DRGUDOD-OPS10              DR
# 1831              7.0   DOD-OPS   4715DRGUDOD-OPS09              DR
# 1838              7.0   DOD-OPS   4715DRGUDOD-OPS08              DR
# 1840              7.0   DOD-OPS   4715DRGUDOD-OPS07              DR
# 1842              7.0   DOD-OPS   4715DRGUDOD-OPS06              DR
# 1844              7.0   DOD-OPS   4715DRGUDOD-OPS05              DR
# 1851              0.0   DOD-OPS   4715DRGUDOD-OPS04              DR
# 1856              0.0   DOD-OPS   4715DRGUDOD-OPS03              DR
# 1860              0.0   DOD-OPS   4715DRGUDOD-OPS02              DR
# 1863              5.0   DOD-OPS   4715DRGUDOD-OPS01              DR
# 1865              7.0   DOD-DLA       4715DRGUDLA01              DR
# 1867              0.0  DHS-USCG  4715DRGUDHS-USCG04              DR
# 1871              0.0  DHS-USCG  4715DRGUDHS-USCG02              DR
# 1873              0.0  DHS-USCG  4715DRGUDHS-USCG01              DR
# 1877             13.0   DHS-FPS   4715DRGUDHS-FPS01              DR
# 1879             14.0  DHS-CISA  4715DRGUDHS-CISA04              DR
# 1882              2.0  DHS-CISA  4715DRGUDHS-CISA03              DR
# 1884             14.0  DHS-CISA  4715DRGUDHS-CISA02              DR
# 1886              2.0  DHS-CISA  4715DRGUDHS-CISA01              DR
# 1890              3.0   COE-POD   4715DRGUCOE-POD05              DR
# 1893              3.0   COE-POD   4715DRGUCOE-POD04              DR
# 1898              6.0   COE-POD   4715DRGUCOE-POD03              DR
# 1905              3.0   COE-POD   4715DRGUCOE-POD02              DR
# 1914              3.0   COE-POD   4715DRGUCOE-POD01              DR
# 1916              3.0    COE-HQ    4715DRGUCOE-HQ01              DR
#
#                                     assistanceRequested  \
# 1773  Activate ESF 4 USFS to the RRCC, IOF JFO or ot...
# 1776  Activate ESF 11 USDA liaison(s) to the  RRCC, ...
# 1778  USDA liaison(s) to the NRCC to perform duties ...
# 1781  HHS to provide DMAT team in support of MAWAR\r...
# 1782  Activate HHS to RRCC, IOF, JFO, RFO, or other ...
# 1784       HHS to provide DMAT team in support of MAWAR
# 1785  Activate HHS to NRCC to perform duties of ESF ...
# 1789  Activate ESF 7 GSA to RRCC, IOF, JFO, or other...
# 1790  Activate GSA to NRCC to perform duties of ESF ...
# 1792  Activate FCC to the NRCC to support Typhoon MA...
# 1795  Region 9 Water Emergency Team (WET) SME to sup...
# 1797  Activate ESF 10 EPA to RRCC, IOF, JFO, or othe...
# 1798  Water/Wastewater SME to NRCC. This MA is repla...
# 1799  EPA to NRCC to perform duties of ESF #10 in su...
# 1801  Activate ESF 1 DOT to RRCC. IOF, JFO, or other...
# 1803  Activate Dot to NRCC to support Typhoon Mawar....
# 1805  Activate DOS to the NRCC to perform LNO duties...
# 1807  Activate ESF 13 DOJ to RRCC, IOF, JFO, or othe...
# 1809  Activate DOJ to NRCC to perform duties of ESF ...
# 1812  Activate DOE to RRCC. IOF, JFO, or other team(...
# 1814  Activate DOE to the NRCC to perform duties of ...
# 1816  Request for assistance with temporary housing ...
# 1818  DOD to provide debris clearance for to the rig...
# 1820  Provide Joint Base Pearl Harbor Hickam (JBPHH)...
# 1823  (DOD) will provide Material Handling Capabilit...
# 1825  DOD to provide manpower and equipment in suppo...
# 1828  DoD will provide Interisland air  transportati...
# 1831  Provide ground transportation to move cargo an...
# 1838  DOD strategic air transportation of personnel ...
# 1840  Provide interisland transportation (Sea) of su...
# 1842  DOD to provide Andersen Airforce Base as a FEM...
# 1844   DOD provide Navel Base Guam  and support faci...
# 1851  Request DCO / DCE West (including as necessary...
# 1856  Request DCO / DCE East (including as necessary...
# 1860  Request DCO / DCE Oakland (including as necess...
# 1863  Activate DOD to NRCC to support Typhoon Mawar....
# 1865  Activate DLA liaisons to NRCC in support of Ty...
# 1867  USCG fixed-wing transportation of personnel an...
# 1871  Request to deploy USCG liaison officer(s) to R...
# 1873  Activate USCG liaison(s) to NRCC in support of...
# 1877  Contract security officers to support the FEMA...
# 1879  Activate CISA-14 LNOs to RRCC, JFO, IOF. This ...
# 1882  Activate CISA ESF-2 to RRCC, IOF, JFO. \r\nThi...
# 1884  Activate CISA LNO to NRCC to perform duties of...
# 1886  Activate CISA to the NRCC to perform duties of...
# 1890  USACE specialized expertise for oversight of d...
# 1893  USACE pre-position resources to provide planni...
# 1898  USACE pre-position the Temporary Roofing SME P...
# 1905  USACE will provide temporary power support ass...
# 1914  Activate ESF #3 USACE to the EOC, RRCC, IOF, J...
# 1916  Activate USACE to the NRCC in support of Typho...
#
#                                         statementOfWork
# 1773  As directed by and in coordination with FEMA, ...
# 1776  As directed by and in coordination with FEMA, ...
# 1778  As directed by and in coordination with FEMA, ...
# 1781  In support of Guam as directed by and in coord...
# 1782  As directed by and in coordination with FEMA, ...
# 1784  In support of Guam as directed by and in coord...
# 1785  As directed by and in coordination with FEMA, ...
# 1789  As directed by and in coordination with FEMA, ...
# 1790  As directed by and in coordination with FEMA, ...
# 1792  As directed by and in coordination with FEMA, ...
# 1795  As directed by and in coordination with FEMA, ...
# 1797  As directed by and in coordination with FEMA, ...
# 1798  As directed by and in coordination with FEMA, ...
# 1799  As directed by and in coordination with FEMA, ...
# 1801  .As directed by and in coordination with FEMA,...
# 1803  As directed by and in coordination with FEMA, ...
# 1805  As directed by and in coordination with FEMA, ...
# 1807  As directed by and in coordination with FEMA, ...
# 1809  As directed by and in coordination with FEMA, ...
# 1812  As directed by and in coordination with FEMA, ...
# 1814  As directed by and in coordination with FEMA, ...
# 1816  DOD to provide personnel, equipment, supplies ...
# 1818  As requested by and in coordination with FEMA,...
# 1820  As requested by and in coordination with FEMA,...
# 1823  As directed by and in coordination with FEMA, ...
# 1825  As directed by and in coordination with FEMA, ...
# 1828  As requested by and in coordination with FEMA ...
# 1831  As requested by and in coordination with FEMA ...
# 1838  As requested by and in coordination with FEMA ...
# 1840  As requested by and in coordination with FEMA ...
# 1842  As requested by and in coordination with FEMA,...
# 1844  As directed by and in coordination with FEMA, ...
# 1851  As directed by and in coordination with FEMA, ...
# 1856  As directed by and in coordination with FEMA, ...
# 1860  As directed by and in coordination with FEMA, ...
# 1863  As directed by and in coordination with FEMA, ...
# 1865  As directed by and in coordination with FEMA, ...
# 1867  As directed by and in coordination with FEMA, ...
# 1871  As directed by and in coordination with FEMA, ...
# 1873  As directed by and in coordination with FEMA, ...
# 1877  As directed by and in coordination with FEMA, ...
# 1879  As directed by and in coordination with FEMA, ...
# 1882  As directed by and in coordination with FEMA, ...
# 1884  As directed by and in coordination with FEMA, ...
# 1886  As directed by and in coordination with FEMA, ...
# 1890  As directed by and in coordination with FEMA, ...
# 1893  As directed by and in coordination with FEMA, ...
# 1898  As directed by and in coordination with FEMA, ...
# 1905  In support of Guam request, as directed by and...
# 1914  As directed by and in coordination with FEMA, ...
# 1916  As directed by and in coordination with FEMA, ...

# %%
df_dds[df_dds['incidentId']==2023052201]
# Out:
# Empty DataFrame
# Columns: [femaDeclarationString, state, incidentType, incidentBeginDate, fipsStateCode, region, designatedIncidentTypes, declarationTitle, incidentId, declarationType, year, month, day]
# Index: []

# %%
MA_disaster_combined['incidentId'].nunique()
# Out:
# 326

# %%
MA_disaster_combined.dropna(inplace=True)

# %%
MA_disaster_combined['incidentId'].nunique()
# Out:
# 321

# %%
MA_disaster_combined[MA_disaster_combined['year']<2023].to_parquet(train_filepath)
MA_disaster_combined[MA_disaster_combined['year']>=2023].to_parquet(test_filepath)
