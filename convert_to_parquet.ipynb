# %%
import pandas as pd

# %% [markdown]
# Adjust display options to show more columns

# %%
pd.set_option('display.max_columns', 80)

# %% [markdown]
# Convert larger .csv files to smaller .parquet files

# %%
df_dds = pd.read_csv('DisasterDeclarationsSummaries.csv')
df_dds.head()
# Out:
# /var/folders/15/mh2mgzhn1191h4zq_5d03wfc0000gn/T/ipykernel_90527/915553188.py:1: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_dds = pd.read_csv('DisasterDeclarationsSummaries.csv')
#   femaDeclarationString  disasterNumber state declarationType  \
# 0            FM-5529-OR            5529    OR              FM
# 1            FM-5528-OR            5528    OR              FM
# 2            FM-5527-OR            5527    OR              FM
# 3            DR-4312-CA            4312    CA              DR
# 4            DR-4251-AL            4251    AL              DR
#
#             declarationDate  fyDeclared  incidentType  \
# 0  2024-08-09T00:00:00.000Z        2024          Fire
# 1  2024-08-06T00:00:00.000Z        2024          Fire
# 2  2024-08-02T00:00:00.000Z        2024          Fire
# 3  2017-05-02T00:00:00.000Z        2017  Severe Storm
# 4  2016-01-21T00:00:00.000Z        2016  Severe Storm
#
# ...

# %%
df_dds.to_parquet('disaster_declaration_summaries.parquet')

# %%
df_ma = pd.read_csv('MissionAssignments.csv')
df_ma.head()
# Out:
#    incidentId                       incidentName    incidentType  \
# 0  2024081901  R1_Severe Storm-Flooding_08182024    Severe Storm
# 1  2024080901   Tropical Disturbance_TS_Ernesto   Tropical Storm
# 2  2024080901   Tropical Disturbance_TS_Ernesto   Tropical Storm
# 3  2024080901   Tropical Disturbance_TS_Ernesto   Tropical Storm
# 4  2024080901   Tropical Disturbance_TS_Ernesto   Tropical Storm
#
#    disasterNumber declarationType  \
# 0          3612.0              EM
# 1             NaN              SU
# 2             NaN              SU
# 3             NaN              SU
# 4             NaN              SU
#
#                                     declarationTitle                  maId  \
# 0  SEVERE STORMS, FLOODING, LANDSLIDES, AND MUDSL...    3612EMCTDOI-USGS01
# 1                                                NaN  PR24080901USDA-APH01
# 2                                                NaN       PR24080901DOT01
# ...

# %%
df_ma.to_parquet('mission_assignments.parquet')

# %% [markdown]
# Read .parquet files and compare to original dataframes for any oddities in file format conversion.

# %%
df = pd.read_parquet('disaster_declaration_summaries.parquet')
df.head()
# Out:
#   femaDeclarationString  disasterNumber state declarationType  \
# 0            FM-5529-OR            5529    OR              FM
# 1            FM-5528-OR            5528    OR              FM
# 2            FM-5527-OR            5527    OR              FM
# 3            DR-4312-CA            4312    CA              DR
# 4            DR-4251-AL            4251    AL              DR
#
#             declarationDate  fyDeclared  incidentType  \
# 0  2024-08-09T00:00:00.000Z        2024          Fire
# 1  2024-08-06T00:00:00.000Z        2024          Fire
# 2  2024-08-02T00:00:00.000Z        2024          Fire
# 3  2017-05-02T00:00:00.000Z        2017  Severe Storm
# 4  2016-01-21T00:00:00.000Z        2016  Severe Storm
#
#                                     declarationTitle  ihProgramDeclared  \
# 0                                     LEE FALLS FIRE                  0
# 1                                      ELK LANE FIRE                  0
# ...

# %%
print(df_dds.shape, df.shape)
# Out:
# (68485, 28) (68485, 28)

# %%
df2 = pd.read_parquet('mission_assignments.parquet')

# %%
df2.head()
# Out:
#    incidentId                       incidentName    incidentType  \
# 0  2024081901  R1_Severe Storm-Flooding_08182024    Severe Storm
# 1  2024080901   Tropical Disturbance_TS_Ernesto   Tropical Storm
# 2  2024080901   Tropical Disturbance_TS_Ernesto   Tropical Storm
# 3  2024080901   Tropical Disturbance_TS_Ernesto   Tropical Storm
# 4  2024080901   Tropical Disturbance_TS_Ernesto   Tropical Storm
#
#    disasterNumber declarationType  \
# 0          3612.0              EM
# 1             NaN              SU
# 2             NaN              SU
# 3             NaN              SU
# 4             NaN              SU
#
#                                     declarationTitle                  maId  \
# 0  SEVERE STORMS, FLOODING, LANDSLIDES, AND MUDSL...    3612EMCTDOI-USGS01
# 1                                               None  PR24080901USDA-APH01
# 2                                               None       PR24080901DOT01
# ...

# %%
print(df_ma.shape, df2.shape)
# Out:
# (40340, 39) (40340, 39)
